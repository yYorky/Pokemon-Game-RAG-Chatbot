# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from datasets import Dataset
from ragas.metrics import AnswerSimilarity, AnswerCorrectness
from ragas.evaluation import evaluate
import os
from dotenv import load_dotenv

load_dotenv()
os.environ['OPENAI_API_KEY'] = os.getenv("OPENAI_API_KEY")
# Out:
# Python-dotenv could not parse statement starting at line 1
# Python-dotenv could not parse statement starting at line 7

# %%
# Load the CSV file
csv_file_path = '../Basline LLM evaluation/Eval_ChatGPT35.csv'

try:
    data = pd.read_csv(csv_file_path, encoding='utf-8')
except UnicodeDecodeError:
    data = pd.read_csv(csv_file_path, encoding='latin1')

# %%
# Define the metrics to be evaluated
metrics = [
    AnswerSimilarity(), 
    AnswerCorrectness()
]

# Initialize columns for results
data['answer_similarity'] = None
data['answer_correctness'] = None

# Iterate over each row to evaluate the metrics individually
for idx, row in data.iterrows():
    evaluation_data = Dataset.from_dict({
        'question': [row['question']],
        'ground_truth': [row['ground_truth']],
        'answer': [row['answer']]
    })
    
    evaluation_result = evaluate(evaluation_data, metrics=metrics)
    
    # Store results back in the DataFrame
    data.at[idx, 'answer_similarity'] = evaluation_result['answer_similarity']
    data.at[idx, 'answer_correctness'] = evaluation_result['answer_correctness']
# Out:
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Task exception was never retrieved
# future: <Task finished name='Task-110' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-111' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-112' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-113' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Task exception was never retrieved
# future: <Task finished name='Task-166' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-167' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-168' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-169' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Task exception was never retrieved
# future: <Task finished name='Task-223' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-224' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Task exception was never retrieved
# future: <Task finished name='Task-280' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-281' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Task exception was never retrieved
# future: <Task finished name='Task-338' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-339' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-340' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-341' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Task exception was never retrieved
# future: <Task finished name='Task-396' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-397' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-398' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-399' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Task exception was never retrieved
# future: <Task finished name='Task-454' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-455' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# ...
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-802' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-803' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-804' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Task exception was never retrieved
# future: <Task finished name='Task-912' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-913' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-914' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Task exception was never retrieved
# future: <Task finished name='Task-915' coro=<AsyncClient.aclose() done, defined at C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py:2011> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_client.py", line 2018, in aclose
#     await self._transport.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpx\_transports\default.py", line 385, in aclose
#     await self._pool.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 313, in aclose
#     await self._close_connections(closing_connections)
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection_pool.py", line 305, in _close_connections
#     await connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\connection.py", line 171, in aclose
#     await self._connection.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_async\http11.py", line 265, in aclose
#     await self._network_stream.aclose()
#   File "C:\Users\York Yong\AppData\Roaming\Python\Python310\site-packages\httpcore\_backends\anyio.py", line 55, in aclose
#     await self._stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\streams\tls.py", line 202, in aclose
#     await self.transport_stream.aclose()
#   File "c:\ProgramData\Anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1181, in aclose
#     self._transport.close()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\proactor_events.py", line 109, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 753, in call_soon
#     self._check_closed()
#   File "c:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 515, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Display the evaluation results
result_df = data[['question', 'ground_truth', 'answer', 'answer_similarity', 'answer_correctness']]
result_df
# Out:
#                                              question  \
# 0   What are the starting choices for Pokémon in P...
# 1   What special mounts are available in Pokémon S...
# 2              How does fast travel work in the game?
# 3    How do you initiate battles with other trainers?
# 4        What can you collect from gimmighoul chests?
# 5          How are items indicated in the game world?
# 6      What benefits do sandwiches offer in the game?
# 7     How can you prevent getting lost using the map?
# 8   What is a recommended tactic for leveling up q...
# 9   What are the three main storylines in Pokémon ...
# 10  What abilities do defeating Titan Pokémon unlock?
# 11  What are the recommended levels for fighting t...
# 12  How does the battle mechanic change with gym l...
# 13  What is the challenge format for Starfall Stre...
# 14  How do you capture a second Koraidon or Miraid...
# 15    How do you breed Pokémon in Scarlet and Violet?
# 16  What is the significance of the "Area Zero" mi...
# 17  What is required to evolve Pokémon like Eevee ...
# 18              How can you earn more LP in the game?
# 19  What type of team is recommended for the Elite...
# 20  How do Tera Raid Battles differ from regular b...
# 21              What is the role of gimmighoul coins?
# 22  How do you obtain special items like the Chipp...
# 23  What is the method to ensure a successful catc...
# 24  What pokemon does Montenevera Chost Gym leader...
# 25    What is the recipe for Electric Shiny Sandwich?
# 26                        Who is the Real Cassiopeia?
# 27    What are the weakness of the Titan Bombirdier?
# 28          Where can I heal my pokemon in Area Zero?
# 29  What moves do I need to battle against the Pro...
# 30  What is required to evolve Charcadet into Arma...
# 31  Which pokemon requires walking with Let's Go t...
# 32  In the Champion Assessment, what is the name o...
# 33            How to defeat Elite Four Member Hassel?
# 34                           Where is Pokemon League?
# 35  How do you turn off the time machine in Area Z...
# 36             Where can you find gimmighoul's chest?
# 37                     Where can I find soothe bells?
# 38  I keep going in the wrong direction, how do I ...
# 39  I've heard I can climb mountains, how do I do ...
# 40                      I can't get past gym 6, help!
# 41                     How do I fight Dragon pokemon?
# 42      What is the final battle mission of the game?
# 43                        How do I get a Polteageist?
# 44      I'm trying to get a Marill, how do I do that?
# 45                            List down all the gyms.
# 46  How does the "Let's Go" feature affect Pokémon...
# 47        What happens after I defeat the Elite Four?
# 48  What level are the Professor's Pokemon in Area...
# 49                        How do I evolve a Sunflora?
#
#                                          ground_truth  \
# 0   The starter Pokémon options in Paldea are Spri...
# 1   Scarlet players can catch and ride Koraidon, w...
# 2   Fast travel is unlocked immediately and can be...
# 3   Unlike past games, you must talk to trainers t...
# 4       You can collect coins from gimmighoul chests.
# 5   Items are indicated by pokeballs or shiny spot...
# 6   Sandwiches provide buffs for 30 minutes durati...
# 7   Press the right analog stick to fix the map or...
# 8   Eating a Ham Sandwich (#80) to increase normal...
# 9   The Gym Challenge, Starfall Street, and the Pa...
# 10  Defeating Titan Pokémon unlocks new abilities ...
# 11  The recommended levels for fighting Klawf are ...
# 12  The final Pokémon used by gym leaders will Ter...
# 13  You must defeat 30 Pokémon in autobattles befo...
# 14  After completing the main story, a second Kora...
# 15  Breeding involves having a Ditto and another P...
# 16  It's a deep exploration mission involving the ...
# 17  Eevee requires specific stones or conditions l...
# 18  LP can be earned through Tera Raid Battles and...
# 19  A diverse team covering multiple types such as...
# 20  They allow multiple players to fight a single,...
# 21  They are used to evolve Gimmighoul into Gholde...
# 22  These can be found on the ground, bought at au...
# 23  Turn off auto-save, use a Master Ball or set u...
# 24  Rymn, the gym leader for Montenevera Ghost Gym...
# 25  You will need the following:\nYellow Bell Pepp...
# 26                       The Real Cassiopeia is Penny
# 26  The Real Cassiopeia in "Pokémon Scarlet and Vi...          0.869616
# 27  The Titan Bombirdier in "Pokémon Scarlet and V...          0.913592
# 28  In Area Zero in "Pokémon Scarlet and Violet," ...          0.853811
# 29  To battle against Professor Turo in "Pokémon S...          0.837087
# 30  To evolve Charcadet into Armarouge in "Pokémon...          0.765826
# 31  In "Pokémon Scarlet and Violet," the Pokémon t...          0.767169
# 32  In the Champion Assessment, the name of the Gy...          0.787016
# 33  To defeat Elite Four Member Hassel in "Pokémon...           0.87154
# 34  The Pokémon League in "Pokémon Scarlet and Vio...          0.817514
# 35  In "Pokémon Scarlet and Violet," turning off t...          0.822215
# 36  In "Pokémon Scarlet and Violet," Gimmighoul's ...          0.731914
# 37  In "Pokémon Scarlet and Violet," you can typic...          0.779149
# 38  To fix consistently going in the wrong directi...          0.848425
# 39  In "Pokémon Scarlet and Violet," you can typic...          0.817586
# 40  To help you get past Gym 6 in "Pokémon Scarlet...          0.836979
# 41  To effectively fight Dragon-type Pokémon in "P...          0.863971
# 42  The final battle mission of the game in "Pokém...          0.828569
# 43  To obtain a Polteageist in "Pokémon Scarlet an...          0.910259
# 44  To obtain a Marill in "Pokémon Scarlet and Vio...          0.819932
# 45  In "Pokémon Scarlet and Violet," the gyms are ...          0.813347
# 46  The "Let's Go" feature in "Pokémon Scarlet and...          0.861103
# 47  After defeating the Elite Four in "Pokémon Sca...          0.846744
# 48  The Professor's Pokémon in Area Zero are typic...          0.810709
# 49  To evolve a Sunflora into a Sunflora in "Pokém...          0.915389
#
#    answer_correctness
# 0            0.681407
# 1            0.211431
# 2            0.649852
# 3            0.227633
# 4            0.215118
# 5            0.725687
# 6            0.215997
# 7            0.196929
# 8            0.197532
# 9            0.205485
# 10           0.598835
# 11           0.211626
# 12           0.328787
# 13            0.20198
# 14           0.719832
# 15            0.21597
# 16           0.422652
# 17           0.553458
# 18           0.213798
# 19           0.604032
# 20           0.786195
# 21           0.215828
# 22           0.204814
# 23           0.439046
# 24           0.221774
# 25            0.18861
# 26           0.217404
# 27           0.728398
# 28           0.213453
# 29           0.481999
# 30            0.19145
# 31           0.191792
# 32           0.196754
# 33           0.432171
# 34           0.204378
# 35           0.205554
# 36           0.182975
# 37           0.194787
# 38           0.407759
# 39           0.204396
# 40           0.349864
# 41           0.562148
# 42           0.207142
# 43           0.870422
# 44           0.204983
# 45           0.203339
# 46           0.402776
# 47             0.7474
# 48           0.577677
# 49           0.228846

# %%
# Print the mean values of answer_similarity and answer_correctness
print("Mean Answer Similarity:", data['answer_similarity'].replace(np.nan, 0).mean())
print("Mean Answer Correctness:", data['answer_correctness'].replace(np.nan, 0).mean())
# Out:
# Mean Answer Similarity: 0.8430862823001819
# Mean Answer Correctness: 0.3612435049663631
